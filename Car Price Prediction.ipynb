# %% [markdown]
# ## Car Price Prediction

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
car = pd.read_csv(r"C:\Users\Dell\Desktop\Machine Learning\Projects\Car Price Prediction\Dataset\quikr_car.csv")

# %%
car
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 887                                      Ta       Tara  zest       3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#      kms_driven fuel_type
# 0    45,000 kms    Petrol
# ...

# %%
car.shape
# Out:
# (892, 6)

# %%
car.head(10)
# Out:
#                                      name   company  year          Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
# 5        Ford EcoSport Titanium 1.5L TDCi      Ford  2015  Ask For Price
# 6                               Ford Figo      Ford  2012       1,75,000
# 7                             Hyundai Eon   Hyundai  2013       1,90,000
# 8        Ford EcoSport Ambiente 1.5L TDCi      Ford  2016       8,30,000
# 9          Maruti Suzuki Alto K10 VXi AMT    Maruti  2015       2,50,000
#
#    kms_driven fuel_type
# 0  45,000 kms    Petrol
# 1      40 kms    Diesel
# 2  22,000 kms    Petrol
# 3  28,000 kms    Petrol
# 4  36,000 kms    Diesel
# ...

# %%
car[(car['company']=='Mahindra') & (car['year']=='2006')]
# Out:
#                          name   company  year     Price kms_driven fuel_type
# 1     Mahindra Jeep CL550 MDI  Mahindra  2006  4,25,000     40 kms    Diesel
# 15    Mahindra Jeep CL550 MDI  Mahindra  2006  4,25,000     40 kms    Diesel
# 382  Mahindra Jeep MM 550 XDB  Mahindra  2006  4,25,000    122 kms    Diesel

# %%
car.dtypes
# Out:
# name          object
# company       object
# year          object
# Price         object
# kms_driven    object
# fuel_type     object
# dtype: object

# %%
# car['year']=pd.to_datetime(car['year'],format='%Y')

# %%
car.dtypes
# Out:
# name          object
# company       object
# year          object
# Price         object
# kms_driven    object
# fuel_type     object
# dtype: object

# %%
# car['year'] = pd.to_numeric(car['year'], errors='coerce').astype('Int64')

# %%
car.dtypes
# Out:
# name          object
# company       object
# year          object
# Price         object
# kms_driven    object
# fuel_type     object
# dtype: object

# %%
car
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 887                                      Ta       Tara  zest       3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#      kms_driven fuel_type
# 0    45,000 kms    Petrol
# ...

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    object
#  3   Price       892 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 41.9+ KB

# %%
car.isna().sum()
# Out:
# name           0
# company        0
# year           0
# Price          0
# kms_driven    52
# fuel_type     55
# dtype: int64

# %%
car['fuel_type'].unique()
# Out:
# array(['Petrol', 'Diesel', nan, 'LPG'], dtype=object)

# %% [markdown]
# ## Data Quality

# %% [raw]
# Year
# -- year column contain non year data that need to remove.
# -- year column need to convert into integar
# Price
# -- 'Ask by price' value are in Price columns that need to remove
# -- numbers contain with comma in Price values.
# Kms_driven
# -- Kms_driven column contain kms and object datatype and need to remove comma
# Fuel_type
# -- fuel_type column contain null values

# %%
backup=car.copy()

# %% [markdown]
# ## Cleaning

# %%
car
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 887                                      Ta       Tara  zest       3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#      kms_driven fuel_type
# 0    45,000 kms    Petrol
# ...

# %%
car=car[car['year'].str.isnumeric()]

# %%
car['year']= pd.to_numeric(car['year'],errors='coerce').astype('Int64')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_18664\3166575615.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car['year']= pd.to_numeric(car['year'],errors='coerce').astype('Int64')

# %%
car.dtypes
# Out:
# name          object
# company       object
# year           Int64
# Price         object
# kms_driven    object
# fuel_type     object
# dtype: object

# %%
car['Price'].unique()
# Out:
# array(['80,000', '4,25,000', 'Ask For Price', '3,25,000', '5,75,000',
#        '1,75,000', '1,90,000', '8,30,000', '2,50,000', '1,82,000',
#        '3,15,000', '4,15,000', '3,20,000', '10,00,000', '5,00,000',
#        '3,50,000', '1,60,000', '3,10,000', '75,000', '1,00,000',
#        '2,90,000', '95,000', '1,80,000', '3,85,000', '1,05,000',
#        '6,50,000', '6,89,999', '4,48,000', '5,49,000', '5,01,000',
#        '4,89,999', '2,80,000', '3,49,999', '2,84,999', '3,45,000',
#        '4,99,999', '2,35,000', '2,49,999', '14,75,000', '3,95,000',
#        '2,20,000', '1,70,000', '85,000', '2,00,000', '5,70,000',
#        '1,10,000', '4,48,999', '18,91,111', '1,59,500', '3,44,999',
#        '4,49,999', '8,65,000', '6,99,000', '3,75,000', '2,24,999',
#        '12,00,000', '1,95,000', '3,51,000', '2,40,000', '90,000',
#        '1,55,000', '6,00,000', '1,89,500', '2,10,000', '3,90,000',
#        '1,35,000', '16,00,000', '7,01,000', '2,65,000', '5,25,000',
# ...

# %%
car['Price']=car['Price'].str.replace(',','')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_18664\2888702569.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car['Price']=car['Price'].str.replace(',','')

# %%
car['Price'].unique()
# Out:
# array(['80000', '425000', 'Ask For Price', '325000', '575000', '175000',
#        '190000', '830000', '250000', '182000', '315000', '415000',
#        '320000', '1000000', '500000', '350000', '160000', '310000',
#        '75000', '100000', '290000', '95000', '180000', '385000', '105000',
#        '650000', '689999', '448000', '549000', '501000', '489999',
#        '280000', '349999', '284999', '345000', '499999', '235000',
#        '249999', '1475000', '395000', '220000', '170000', '85000',
#        '200000', '570000', '110000', '448999', '1891111', '159500',
#        '344999', '449999', '865000', '699000', '375000', '224999',
#        '1200000', '195000', '351000', '240000', '90000', '155000',
#        '600000', '189500', '210000', '390000', '135000', '1600000',
#        '701000', '265000', '525000', '372000', '635000', '550000',
#        '485000', '329500', '251111', '569999', '69999', '299999',
#        '399999', '450000', '270000', '158400', '179000', '125000',
# ...

# %%
car=car[car['Price']!='Ask For Price']

# %%
car['Price']=car['Price'].astype(int)

# %%
car=car[car['kms_driven']!='Petrol']

# %%
car
# Out:
#                                        name   company  year   Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000
# 1                   Mahindra Jeep CL550 MDI  Mahindra  2006  425000
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000
# 4          Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000
# 6                                 Ford Figo      Ford  2012  175000
# ..                                      ...       ...   ...     ...
# 883              Maruti Suzuki Ritz VXI ABS    Maruti  2011  270000
# 885               Tata Indica V2 DLE BS III      Tata  2009  110000
# 886                    Toyota Corolla Altis    Toyota  2009  300000
# 888                     Tata Zest XM Diesel      Tata  2018  260000
# 889                      Mahindra Quanto C8  Mahindra  2013  390000
#
#        kms_driven fuel_type
# 0      45,000 kms    Petrol
# 1          40 kms    Diesel
# 3      28,000 kms    Petrol
# 4      36,000 kms    Diesel
# ...

# %%
car[['kms_num','kms']]=car['kms_driven'].str.split(' ',expand=True)

# %%
car=car.drop('kms_driven',axis=1)

# %%
car['kms_num']=car['kms_num'].str.replace(',','')

# %%
car['kms_num']=car['kms_num'].astype(int)

# %%
car['name'].str.split()
# Out:
# 0        [Hyundai, Santro, Xing, XO, eRLX, Euro, III]
# 1                        [Mahindra, Jeep, CL550, MDI]
# 3      [Hyundai, Grand, i10, Magna, 1.2, Kappa, VTVT]
# 4              [Ford, EcoSport, Titanium, 1.5L, TDCi]
# 6                                        [Ford, Figo]
#                             ...
# 883                  [Maruti, Suzuki, Ritz, VXI, ABS]
# 885                  [Tata, Indica, V2, DLE, BS, III]
# 886                          [Toyota, Corolla, Altis]
# 888                          [Tata, Zest, XM, Diesel]
# 889                            [Mahindra, Quanto, C8]
# Name: name, Length: 817, dtype: object

# %%
car=car.drop('kms',axis=1)

# %%
car=car.rename(columns=({'kms_num':'kms_driven'}))

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 817 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        817 non-null    object
#  1   company     817 non-null    object
#  2   year        817 non-null    Int64
#  3   Price       817 non-null    int32
#  4   fuel_type   816 non-null    object
#  5   kms_driven  817 non-null    int32
# dtypes: Int64(1), int32(2), object(3)
# memory usage: 39.1+ KB

# %%
car=car.dropna(subset=['fuel_type'])

# %%
car=car.reset_index(drop=True)

# %%
car
# Out:
#                                        name   company  year   Price fuel_type  \
# 0      Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000    Petrol
# 1                   Mahindra Jeep CL550 MDI  Mahindra  2006  425000    Diesel
# 2    Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000    Petrol
# 3          Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000    Diesel
# 4                                 Ford Figo      Ford  2012  175000    Diesel
# ..                                      ...       ...   ...     ...       ...
# 811              Maruti Suzuki Ritz VXI ABS    Maruti  2011  270000    Petrol
# 812               Tata Indica V2 DLE BS III      Tata  2009  110000    Diesel
# 813                    Toyota Corolla Altis    Toyota  2009  300000    Petrol
# 814                     Tata Zest XM Diesel      Tata  2018  260000    Diesel
# 815                      Mahindra Quanto C8  Mahindra  2013  390000    Diesel
#
#      kms_driven
# ...

# %%
car['name']=car['name'].str.split(' ').str[:3].str.join(' ')

# %%
car
# Out:
#                        name   company  year   Price fuel_type  kms_driven
# 0       Hyundai Santro Xing   Hyundai  2007   80000    Petrol       45000
# 1       Mahindra Jeep CL550  Mahindra  2006  425000    Diesel          40
# 2         Hyundai Grand i10   Hyundai  2014  325000    Petrol       28000
# 3    Ford EcoSport Titanium      Ford  2014  575000    Diesel       36000
# 4                 Ford Figo      Ford  2012  175000    Diesel       41000
# ..                      ...       ...   ...     ...       ...         ...
# 811      Maruti Suzuki Ritz    Maruti  2011  270000    Petrol       50000
# 812          Tata Indica V2      Tata  2009  110000    Diesel       30000
# 813    Toyota Corolla Altis    Toyota  2009  300000    Petrol      132000
# 814            Tata Zest XM      Tata  2018  260000    Diesel       27000
# 815      Mahindra Quanto C8  Mahindra  2013  390000    Diesel       40000
#
# [816 rows x 6 columns]

# %%
car=car[car['Price']<6e6].reset_index(drop=True)

# %%
car
# Out:
#                        name   company  year   Price fuel_type  kms_driven
# 0       Hyundai Santro Xing   Hyundai  2007   80000    Petrol       45000
# 1       Mahindra Jeep CL550  Mahindra  2006  425000    Diesel          40
# 2         Hyundai Grand i10   Hyundai  2014  325000    Petrol       28000
# 3    Ford EcoSport Titanium      Ford  2014  575000    Diesel       36000
# 4                 Ford Figo      Ford  2012  175000    Diesel       41000
# ..                      ...       ...   ...     ...       ...         ...
# 810      Maruti Suzuki Ritz    Maruti  2011  270000    Petrol       50000
# 811          Tata Indica V2      Tata  2009  110000    Diesel       30000
# 812    Toyota Corolla Altis    Toyota  2009  300000    Petrol      132000
# 813            Tata Zest XM      Tata  2018  260000    Diesel       27000
# 814      Mahindra Quanto C8  Mahindra  2013  390000    Diesel       40000
#
# [815 rows x 6 columns]

# %%
car.to_csv('Cleaned_Car.csv', index=False)

# %%
car=pd.read_csv(r"C:\Users\Dell\Desktop\Machine Learning\Projects\Car Price Prediction\Dataset\Cleaned_Car.csv")

# %%
car
# Out:
#                        name   company  year   Price fuel_type  kms_driven
# 0       Hyundai Santro Xing   Hyundai  2007   80000    Petrol       45000
# 1       Mahindra Jeep CL550  Mahindra  2006  425000    Diesel          40
# 2         Hyundai Grand i10   Hyundai  2014  325000    Petrol       28000
# 3    Ford EcoSport Titanium      Ford  2014  575000    Diesel       36000
# 4                 Ford Figo      Ford  2012  175000    Diesel       41000
# ..                      ...       ...   ...     ...       ...         ...
# 810      Maruti Suzuki Ritz    Maruti  2011  270000    Petrol       50000
# 811          Tata Indica V2      Tata  2009  110000    Diesel       30000
# 812    Toyota Corolla Altis    Toyota  2009  300000    Petrol      132000
# 813            Tata Zest XM      Tata  2018  260000    Diesel       27000
# 814      Mahindra Quanto C8  Mahindra  2013  390000    Diesel       40000
#
# [815 rows x 6 columns]

# %% [markdown]
# ## Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# ### Train and Test SPlit

# %%
x = car.drop('Price',axis=1)

# %%
y = car['Price']

# %%
x
# Out:
#                        name   company  year fuel_type  kms_driven
# 0       Hyundai Santro Xing   Hyundai  2007    Petrol       45000
# 1       Mahindra Jeep CL550  Mahindra  2006    Diesel          40
# 2         Hyundai Grand i10   Hyundai  2014    Petrol       28000
# 3    Ford EcoSport Titanium      Ford  2014    Diesel       36000
# 4                 Ford Figo      Ford  2012    Diesel       41000
# ..                      ...       ...   ...       ...         ...
# 810      Maruti Suzuki Ritz    Maruti  2011    Petrol       50000
# 811          Tata Indica V2      Tata  2009    Diesel       30000
# 812    Toyota Corolla Altis    Toyota  2009    Petrol      132000
# 813            Tata Zest XM      Tata  2018    Diesel       27000
# 814      Mahindra Quanto C8  Mahindra  2013    Diesel       40000
#
# [815 rows x 5 columns]

# %%
y
# Out:
# 0       80000
# 1      425000
# 2      325000
# 3      575000
# 4      175000
#         ...
# 810    270000
# 811    110000
# 812    300000
# 813    260000
# 814    390000
# Name: Price, Length: 815, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=0.2)

# %%
ohe = OneHotEncoder(handle_unknown='ignore')
ohe.fit(x[['name','company','fuel_type']])
# Out:
# OneHotEncoder(handle_unknown='ignore')

# %%
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline

# %%
column_trans = make_column_transformer((OneHotEncoder(categories=ohe.categories_),['name','company','fuel_type']),
                                      remainder='passthrough')

# %%
lr = LinearRegression()

# %%
pipe =make_pipeline(column_trans,lr)

# %%
pipe.fit(x_train,y_train)
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\sklearn\compose\_column_transformer.py:1651: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Audi A3 Cabriolet', 'Audi A4 1.8', 'Audi A4 2.0', 'Audi A6 2.0',
#        'Audi A8', 'Audi Q3 2.0', 'Audi Q5 2.0', 'Audi Q7', 'BMW 3 Series',
# ...

# %%
y_predict=pipe.predict(x_test)

# %%
y_predict
# Out:
# array([ 320002.22880693,  272908.79066358,  666667.76115024,
#         479373.9547648 ,  344024.16995664,  336645.49684346,
#         429554.0687889 ,  147136.81982989,   19783.96477596,
#         718140.35401772,  490669.28148977,  533174.47900793,
#         674792.88670368,   16073.47640818,  486371.74147312,
#         244752.61968962,  259746.05251367,  394433.67724812,
#         202157.47214557,  259179.34935521,  433896.94555248,
#         384797.12257188,  347351.21467938,  367876.16617083,
#         431568.57696579,  -52874.53928532,  427119.81175451,
#         137596.53450549,  403908.62430274,   25283.29125939,
#         538010.10951786,  306056.34535496, 1157656.96075068,
#         604965.3753306 ,  513152.49771387,  332007.93191803,
#         114485.78963648, 1579578.08507377,  534437.58532617,
#         195555.96360642,  348714.71467968, -182951.5715471 ,
#         507779.09190299, 1874697.07067274,  268320.94947536,
# ...

# %%
r2_score(y_test,y_predict)
# Out:
# 0.8457042416667213

# %%
score =[]
for i in range(1000):
    x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=0.2, random_state=i)
    lr = LinearRegression()
    pipe = make_pipeline(column_trans,lr)
    pipe.fit(x_train,y_train)
    y_pred=pipe.predict(x_test)
    r2_score(y_test,y_pred)
    score.append(r2_score(y_test,y_pred))

# %%
import numpy as np

# %%
np.argmax(score)
# Out:
# 433

# %%
score[np.argmax(score)]
# Out:
# 0.8457042416667213

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=0.2, random_state=np.argmax(score))
lr = LinearRegression()
pipe = make_pipeline(column_trans,lr)
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)
r2_score(y_test,y_pred)
# Out:
# 0.8457042416667213

# %%
pipe.predict(pd.DataFrame([['Maruti Suzuki Ritz','Maruti',2019,'Petrol',100]],
                         columns=['name','company','year','fuel_type','kms_driven']))
# Out:
# array([515312.8231964])

# %%
 import pickle

# %%
pickle.dump(pipe,open(r"C:\Users\Dell\Desktop\Machine Learning\Projects\Car Price Prediction\Dataset\LinearRegressionModel.pkl",'wb'))

# %%
pickle.dump(ohe, open("OneHotEncoder.pkl", "wb"))

# %%
pipe.predict(pd.DataFrame([['Maruti Suzuki Ritz','Maruti',2019,'Petrol',100]],
                         columns=['name','company','year','fuel_type','kms_driven']))
# Out:
# array([515312.8231964])
